# %% [markdown]
# <a href="https://colab.research.google.com/github/lokithasans2/Data-Analytics-using-Python-Project/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    'Name':['Suruthis','Manoj','Adhil','Sakthi','Saifulla'],
    'sales':[1000,None,3000,1299,None]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name   sales
# 0  Suruthis  1000.0
# 1     Manoj     NaN
# 2     Adhil  3000.0
# 3    Sakthi  1299.0
# 4  Saifulla     NaN

# %%
print(df.isnull())
# Out:
#     Name  sales
# 0  False  False
# 1  False   True
# 2  False  False
# 3  False  False
# 4  False   True

# %%
clean_df = df.dropna()
print(clean_df)
# Out:
#        Name   sales
# 0  Suruthis  1000.0
# 2     Adhil  3000.0
# 3    Sakthi  1299.0

# %%
df.fillna(0, inplace=True)
print(df)
# Out:
#        Name   sales
# 0  Suruthis  1000.0
# 1     Manoj     0.0
# 2     Adhil  3000.0
# 3    Sakthi  1299.0
# 4  Saifulla     0.0

# %%
import pandas as pd

data = {
    'Marks': [50,60,70, None]
}

df = pd.DataFrame(data)

mean_value = df['Marks'].mean()

df["Marks"].fillna(mean_value, inplace=True)

print(df)
# Out:
#    Marks
# 0   50.0
# 1   60.0
# 2   70.0
# 3   60.0
# /tmp/ipykernel_1323/1218552828.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Marks"].fillna(mean_value, inplace=True)

# %%
import pandas as pd

employees = {
    "Emp_ID": [101, 102, 103, 104, 105],
    "Name": ["Suruthis", "Saifulla", "Manoj", "Sakthi", "Adhil"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [45000, 40000, 50000, 55000, 42000],
    "Experience": [2, 3, 5, 6, 4]
}

df = pd.DataFrame(employees)

print("Employee Dataset")
print(df)

print("\nAverage Salary")
print(df["Salary"].mean())

print("\nHighest Salary")
print(df["Salary"].max())

print("\nEmployees in HR")
print(df[df["Department"] == "HR"])

print("\nEmployees with Experience > 3")
print(df[df["Experience"] > 3])

print("\nEmployee Count by Department")
print(df["Department"].value_counts())
# Out:
# Employee Dataset
#    Emp_ID      Name Department  Salary  Experience
# 0     101  Suruthis         IT   45000           2
# 1     102  Saifulla         HR   40000           3
# 2     103     Manoj         IT   50000           5
# 3     104    Sakthi    Finance   55000           6
# 4     105     Adhil         HR   42000           4
#
# Average Salary
# 46400.0
#
# Highest Salary
# 55000
#
# Employees in HR
#    Emp_ID      Name Department  Salary  Experience
# 1     102  Saifulla         HR   40000           3
# 4     105     Adhil         HR   42000           4
#
# Employees with Experience > 3
#    Emp_ID    Name Department  Salary  Experience
# 2     103   Manoj         IT   50000           5
# 3     104  Sakthi    Finance   55000           6
# 4     105   Adhil         HR   42000           4
#
# Employee Count by Department
# Department
# IT         2
# HR         2
# Finance    1
# Name: count, dtype: int64
