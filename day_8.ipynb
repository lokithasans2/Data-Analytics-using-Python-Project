# %% [markdown]
# <a href="https://colab.research.google.com/github/lokithasans2/Data-Analytics-using-Python-Project/blob/main/day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
months = ["Jan", "Feb", "Mar", "Apr", "May"]

sales = [10000, 12000, 15000, 13000, 18000]

plt.plot(months, sales)

plt.title("Monthly Sales")

plt.xlabel("Months")

plt.ylabel("Sales Amount")

plt.show()

# %%
import matplotlib.pyplot as plt
students = ["A", "B", "C", "D", "E"]

marks = [90,40,58,67,89]

plt.bar(students,marks)

plt.title("Monthly Sales")

plt.xlabel("Months")

plt.ylabel("Sales Amount")

plt.show()
